# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('athlete_events.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# merga!

# %% [markdown]
# ### a - hur många länder är med?

# %%
# antal National olympic committe code vilket är där länderna står,
# men Yemen har tex 3 st NOC
# I Serbien ingår även Montenegro, så där är 2 länder i ett
# En NOC är inte ett land utan flyktingar
# Newfoundland, en provins i kanada, är med som NOC också, ej eget land
# Vissa öar har egen NOC även om de tillhör ett land
# så det är svårt att svara på frågan om hur många länder som är med! CIRKA 230 st 

# amount of country codes -> 230 st --> mkt fler lag 1184- vad är Teams?

df['NOC'].unique().shape
# Out:
# (230,)

# %% [markdown]
# ### b - vilka länder är med?

# %%
df['NOC'].unique() # --> landskoder, men det är tex 3 olika för yemen (olika delar), 
                    #men vi ser iaf vilka länder som är med
                    # NOC = National Olympic Committee 3 letter code
# Out:
# array(['CHN', 'DEN', 'NED', 'USA', 'FIN', 'NOR', 'ROU', 'EST', 'FRA',
#        'MAR', 'ESP', 'EGY', 'IRI', 'BUL', 'ITA', 'CHA', 'AZE', 'SUD',
#        'RUS', 'ARG', 'CUB', 'BLR', 'GRE', 'CMR', 'TUR', 'CHI', 'MEX',
#        'URS', 'NCA', 'HUN', 'NGR', 'ALG', 'KUW', 'BRN', 'PAK', 'IRQ',
#        'UAR', 'LIB', 'QAT', 'MAS', 'GER', 'CAN', 'IRL', 'AUS', 'RSA',
#        'ERI', 'TAN', 'JOR', 'TUN', 'LBA', 'BEL', 'DJI', 'PLE', 'COM',
#        'KAZ', 'BRU', 'IND', 'KSA', 'SYR', 'MDV', 'ETH', 'UAE', 'YAR',
#        'INA', 'PHI', 'SGP', 'UZB', 'KGZ', 'TJK', 'EUN', 'JPN', 'CGO',
#        'SUI', 'BRA', 'FRG', 'GDR', 'MON', 'ISR', 'URU', 'SWE', 'ISV',
#        'SRI', 'ARM', 'CIV', 'KEN', 'BEN', 'UKR', 'GBR', 'GHA', 'SOM',
#        'LAT', 'NIG', 'MLI', 'AFG', 'POL', 'CRC', 'PAN', 'GEO', 'SLO',
#        'CRO', 'GUY', 'NZL', 'POR', 'PAR', 'ANG', 'VEN', 'COL', 'BAN',
#        'PER', 'ESA', 'PUR', 'UGA', 'HON', 'ECU', 'TKM', 'MRI', 'SEY',
# ...

# %%
df.sample(5)
# Out:
#            ID                      Name Sex   Age  Height  Weight  \
# 50174   25817      Sharon Day (-Monroe)   F  27.0   180.0    73.0
# 37771   19398       Rudolf "Rudi" Cerne   M  21.0   179.0    69.0
# 192006  96409     Francesco Postiglione   M  28.0   186.0    81.0
# 62860   32223  Lewis Robert "Lew" Elder   M  23.0   175.0     NaN
# 75032   38076       Alessandra Galiotto   F  24.0   180.0    70.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 50174   United States  USA  2012 Summer  2012  Summer       London
# 37771    West Germany  FRG  1980 Winter  1980  Winter  Lake Placid
# 192006          Italy  ITA  2000 Summer  2000  Summer       Sydney
# 62860          Canada  CAN  1928 Summer  1928  Summer    Amsterdam
# 75032           Italy  ITA  2008 Summer  2008  Summer      Beijing
#
#                  Sport                                     Event Medal
# 50174        Athletics              Athletics Women's Heptathlon   NaN
# ...

# %% [markdown]
# ### c - sporter

# %%
df["Sport"].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %% [markdown]
# ### d - medaljtyper

# %%
# medaljtyper

df["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %% [markdown]
# ### e - Statistik för åldern på deltagare

# %%
df['Age'].describe()
# Out:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### f - utforska datan vidare med andra frågor

# %% [markdown]
# vilka fick guldmedaljer första året? Om vi vill veta hur många - plotta!

# %%
df.sort_values(by='Year')
first_year_data= df[df['Year'] == 1896]
first_year_data[first_year_data['Medal'] == 'Gold']['Team'].unique()
# Out:
# array(['Greece', 'Germany', 'Great Britain', 'Great Britain/Germany',
#        'United States', 'Australia', 'France', 'Hungary', 'Denmark',
#        'Austria', 'Switzerland'], dtype=object)

# %% [markdown]
# Vilka länder med i udda och nischade sporter?
# Military Skii patrol. Tug-of-war. Jeu-de-Paume. Bobsleigh. Roque. Luge.
# Det verkar som att bara Spanien tävlade i Basque Pelota

# %%
# Basque Pelota

print(df[df['Sport'] == 'Basque Pelota']['Team'].unique())  
df[df['Sport'] == 'Basque Pelota']['Games'].unique()
# Out:
# ['Spain']
# array(['1900 Summer'], dtype=object)

# %% [markdown]
# Intressant att sporten Military Ski Patrol var med 1924. Mitt emellan världskrigen.

# %%
df[df['Sport']=='Military Ski Patrol']['Games']
# Out:
# 10854     1924 Winter
# 20555     1924 Winter
# 21412     1924 Winter
# 21910     1924 Winter
# 28801     1924 Winter
# 31248     1924 Winter
# 41380     1924 Winter
# 53905     1924 Winter
# 64818     1924 Winter
# 72038     1924 Winter
# 96463     1924 Winter
# 110691    1924 Winter
# 111154    1924 Winter
# 111156    1924 Winter
# 111802    1924 Winter
# 130866    1924 Winter
# 148194    1924 Winter
# 148195    1924 Winter
# 152844    1924 Winter
# 160484    1924 Winter
# 249740    1924 Winter
# 250618    1924 Winter
# 262122    1924 Winter
# 263099    1924 Winter
# Name: Games, dtype: object

# %% [markdown]
# Jeu De Paume deltog bara USA och GBR. Endast 1908

# %%
# Jeu-de-Paume

df[df['Sport']=='Jeu De Paume']
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 21488    11349  Edwin Anthony Biedermann (-Best)   M  30.0     NaN     NaN
# 37344    19192          William Marshall Cazalet   M  42.0     NaN     NaN
# 82805    42060                     Jay Gould, II   M  19.0     NaN     NaN
# 144851   72692     Neville Stephen Bulwer-Lytton   M  29.0     NaN     NaN
# 158944   79794            Eustace Hamilton Miles   M  39.0     NaN     NaN
# 172623   86723                 Evan Baillie Noel   M  29.0     NaN     NaN
# 180169   90545                       Arthur Page   M  32.0     NaN     NaN
# 180736   90836             Arnold Nottage Palmer   M  21.0     NaN     NaN
# 185106   93046           Vane Hungerford Pennell   M  31.0   176.0     NaN
# 209896  105390              Charles Edward Sands   M  42.0   181.0     NaN
# 236826  118745             Charles Edmund Tatham   M  43.0     NaN     NaN
#
# ...

# %% [markdown]
# En är 10 och en är typ 90! Intressant att se vilka sporter o hur det gick!
# Det var i konst och gymnastik och länge sedan! Tror inte att det ålderspannnet finns kvar idag...

# %%
df[df['Age']==97]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %%
df[df['Age'] == 10]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %% [markdown]
# ### g - Diagram över könsfördelningen (COUNTPLOT)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Sex', palette='Set2')   #nytt med sns.countplot!
plt.title('Number of male and female athletes')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\jubel\AppData\Local\Temp\ipykernel_1472\4082042946.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sex', palette='Set2')   #nytt med sns.countplot!

# %% [markdown]
# ### h - Diagram över topp 10 länder som tagit flest medaljer (BARPLOT)

# %%
# filtra ut länder som INTE ha null på Medal

medals = df.dropna(subset=['Medal'])
medals

# räkna medaljer per land
top_10_countries = medals["NOC"].value_counts().head(10)
top_10_countries

# plotta top 10 länderna
plt.figure(figsize=(10, 5))
sns.barplot(x=top_10_countries.index, y=top_10_countries.values, palette='muted')
plt.title('10 countries with most medals')
plt.xlabel('Country code')
plt.ylabel('Total medals')
plt.show()
# Out:
# C:\Users\jubel\AppData\Local\Temp\ipykernel_1472\1138471887.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_countries.index, y=top_10_countries.values, palette='muted')

# %% [markdown]
# ### i - plotta andra saker om är intressant

# %%
# IDÉER


# Vilka länder var top 10 i början? det var ändå 1896. vilka länder var med då ens?

# USA har vunnit flest - linje graf över tid när de vunnit sina medaljer

#vilka fick guldmedaljer första året? Om vi vill veta hur många - plotta!

# Det verkar som att det är rikare länder det gått bra för.

# kanske vilka vinner beroende på ställe. - är det vanligt att det går bra i egna landet?

# Vad händer under eller efter världskrig eller ekonomiska kriser?

# när tog länder flest medaljer??

# nånting med under vilket tidsspann atleterna får sina medaljer - hur många år är atleterna aktiva?

# %%
# filtrera så att vi får bara de första 20 åren hur? loc söka efter tidsintervall

# test iloc()  value_count() isnull() !!! för övning . och mer groupby()
